# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv("../data/StudentsPerformance.csv")
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Math Operations

# %% [markdown]
# ## Operations in columns

# %%
# select a column and calculate total sum
df_exams['math score'].sum()
# Out:
# np.int64(66089)

# %%
# count, mean, std, max and min
df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].max()
df_exams['math score'].min()
# Out:
# np.int64(0)

# %%
# easier calculation with .describe()
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Operations in rows

# %%
# calculating the sum in a row
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
# calculating the average score and assigning the result to a new column
df_exams['average'] = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'])/3

# %%
# showing the dataframe
df_exams.round(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  average
# 0                      none          72             72             74    72.67
# 1                 completed          69             90             88    82.33
# 2                      none          90             95             93    92.67
# 3                      none          47             57             44    49.33
# 4                      none          76             78             75    76.33
# ..                      ...         ...            ...            ...      ...
# 995               completed          88             99             95    94.00
# 996                    none          62             55             55    57.33
# 997               completed          59             71             65    65.00
# 998               completed          68             78             77    74.33
# 999                    none          77             86             86    83.00
#
# [1000 rows x 9 columns]

# %%
df_exams['average'].max()
# Out:
# np.float64(100.0)

# %% [markdown]
# # Value Counts

# %%
# counting gender elements

# len function
len(df_exams['gender'])
# .count() method
df_exams['gender'].count()
# Out:
# np.int64(1000)

# %%
# counting gender elements by category
df_exams['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# return the relative frequency (divide all values by the sum of values)
df_exams['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
# counting "parental level of education" elements by category
df_exams['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
# return the relative frequency and round to 2 decimals
df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, dtype: float64

# %% [markdown]
# # Sort a DataFrame

# %%
# sort by one column
df_exams.sort_values('average')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 712  female        group D                some college      standard
# 114  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 916    male        group E           bachelor's degree      standard
# 458  female        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 59                     none           0             17             10
# 980                    none           8             24             23
# 596                    none          30             24             15
# 327                    none          28             23             19
# 17                     none          18             32             28
# ..                      ...         ...            ...            ...
# 712                    none          98            100             99
# 114               completed          99            100            100
# 962                    none         100            100            100
# 916               completed         100            100            100
# 458                    none         100            100            100
#
#         average
# 59     9.000000
# 980   18.333333
# 596   23.000000
# 327   23.333333
# 17    26.000000
# ..          ...
# 712   99.000000
# 114   99.666667
# 962  100.000000
# 916  100.000000
# 458  100.000000
#
# [1000 rows x 9 columns]

# %%
# sort descending by one column
df_exams.sort_values('average', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 114  female        group E           bachelor's degree      standard
# 712  female        group D                some college      standard
# ..      ...            ...                         ...           ...
# 17   female        group B            some high school  free/reduced
# 327    male        group A                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 916               completed         100            100            100
# 962                    none         100            100            100
# 458                    none         100            100            100
# 114               completed          99            100            100
# 712                    none          98            100             99
# ..                      ...         ...            ...            ...
# 17                     none          18             32             28
# 327                    none          28             23             19
# 596                    none          30             24             15
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#         average
# 916  100.000000
# 962  100.000000
# 458  100.000000
# 114   99.666667
# 712   99.000000
# ..          ...
# 17    26.000000
# 327   23.333333
# 596   23.000000
# 980   18.333333
# 59     9.000000
#
# [1000 rows x 9 columns]

# %%
# sort descending by multiple columns
df_exams.sort_values(['math score', 'reading score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#         average
# 149   97.666667
# 458  100.000000
# 916  100.000000
# 962  100.000000
# 625   98.666667
# ..          ...
# 145   31.333333
# 787   29.666667
# 17    26.000000
# 980   18.333333
# 59     9.000000
#
# [1000 rows x 9 columns]

# %%
# sort descending by multiple columns and update dataframe
df_exams.sort_values(['math score', 'reading score'], ascending=False, inplace=True)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#         average
# 149   97.666667
# 458  100.000000
# 916  100.000000
# 962  100.000000
# 625   98.666667
# ..          ...
# 145   31.333333
# 787   29.666667
# 17    26.000000
# 980   18.333333
# 59     9.000000
#
# [1000 rows x 9 columns]

# %%
# sort descending by text column
df_exams.sort_values('race/ethnicity', ascending=True)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# 741                    none          37             57             56
# 151                    none          77             67             68
# 811                    none          45             47             49
# 112                    none          54             53             47
# 25                     none          73             74             72
# ..                      ...         ...            ...            ...
# 751                    none          68             72             65
# 915                    none          68             70             66
# 592                    none          68             68             64
# 479                    none          76             71             67
# 517               completed          66             74             73
#
#        average
# 741  50.000000
# 151  70.666667
# 811  47.000000
# 112  51.333333
# 25   73.000000
# ..         ...
# 751  68.333333
# 915  68.000000
# 592  66.666667
# 479  71.333333
# 517  71.000000
#
# [1000 rows x 9 columns]

# %%
# sort descending with a key function
df_exams.sort_values('race/ethnicity', ascending=True, key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# 741                    none          37             57             56
# 151                    none          77             67             68
# 811                    none          45             47             49
# 112                    none          54             53             47
# 25                     none          73             74             72
# ..                      ...         ...            ...            ...
# 751                    none          68             72             65
# 915                    none          68             70             66
# 592                    none          68             68             64
# 479                    none          76             71             67
# 517               completed          66             74             73
#
#        average
# 741  50.000000
# 151  70.666667
# 811  47.000000
# 112  51.333333
# 25   73.000000
# ..         ...
# 751  68.333333
# 915  68.000000
# 592  66.666667
# 479  71.333333
# 517  71.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Create Index

# %%
import numpy as np
import random

# %%
# creating non repetative values for the index
new_index = np.arange(0, 1000)

# %%
# shuffling the indexes
random.shuffle(new_index)

# %%
# create a new column with new index
df_exams['new_index'] = new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#         average  new_index
# 149   97.666667        118
# 458  100.000000        970
# 916  100.000000        560
# 962  100.000000         42
# 625   98.666667        503
# ..          ...        ...
# 145   31.333333         64
# 787   29.666667        872
# 17    26.000000        802
# 980   18.333333        458
# 59     9.000000        864
#
# [1000 rows x 10 columns]

# %% [markdown]
# # Set Index

# %%
# set new_index column as index
df_exams.set_index('new_index', inplace=True)
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 118          male        group E          associate's degree  free/reduced
# 970        female        group E           bachelor's degree      standard
# 560          male        group E           bachelor's degree      standard
# 42         female        group E          associate's degree      standard
# 503          male        group D                some college      standard
# ...           ...            ...                         ...           ...
# 64         female        group C                some college  free/reduced
# 872        female        group B                some college      standard
# 802        female        group B            some high school  free/reduced
# 458        female        group B                 high school  free/reduced
# 864        female        group C            some high school  free/reduced
#
#           test preparation course  math score  reading score  writing score  \
# new_index
# 118                     completed         100            100             93
# 970                          none         100            100            100
# 560                     completed         100            100            100
# 42                           none         100            100            100
# 503                     completed         100             97             99
# ...                           ...         ...            ...            ...
# 64                           none          22             39             33
# 872                          none          19             38             32
# 802                          none          18             32             28
# 458                          none           8             24             23
# 864                          none           0             17             10
#
#               average
# new_index
# 118         97.666667
# 970        100.000000
# 560        100.000000
# 42         100.000000
# 503         98.666667
# ...               ...
# 64          31.333333
# 872         29.666667
# 802         26.000000
# 458         18.333333
# 864          9.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Sort Index

# %%
# sort dataframe by new index
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0          female        group D                 high school      standard
# 1          female        group C                some college      standard
# 2            male        group E            some high school      standard
# 3            male        group D                some college      standard
# 4          female        group D          associate's degree  free/reduced
# ...           ...            ...                         ...           ...
# 995        female        group C                 high school      standard
# 996          male        group B                 high school      standard
# 997        female        group C          associate's degree      standard
# 998          male        group E           bachelor's degree  free/reduced
# 999          male        group B             master's degree  free/reduced
#
#           test preparation course  math score  reading score  writing score  \
# new_index
# 0                            none          69             77             73
# 1                            none          54             48             52
# 2                       completed          68             51             57
# 3                            none          67             64             70
# 4                            none          52             59             56
# ...                           ...         ...            ...            ...
# 995                     completed          60             64             74
# 996                     completed          73             71             68
# 997                          none          58             73             68
# 998                     completed          79             74             72
# 999                          none          49             53             52
#
#              average
# new_index
# 0          73.000000
# 1          51.333333
# 2          58.666667
# 3          67.000000
# 4          55.666667
# ...              ...
# 995        66.000000
# 996        70.666667
# 997        66.333333
# 998        75.000000
# 999        51.333333
#
# [1000 rows x 9 columns]

# %%
# sort descending by index
df_exams.sort_index(ascending=False, inplace=True)
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999          male        group B             master's degree  free/reduced
# 998          male        group E           bachelor's degree  free/reduced
# 997        female        group C          associate's degree      standard
# 996          male        group B                 high school      standard
# 995        female        group C                 high school      standard
# ...           ...            ...                         ...           ...
# 4          female        group D          associate's degree  free/reduced
# 3            male        group D                some college      standard
# 2            male        group E            some high school      standard
# 1          female        group C                some college      standard
# 0          female        group D                 high school      standard
#
#           test preparation course  math score  reading score  writing score  \
# new_index
# 999                          none          49             53             52
# 998                     completed          79             74             72
# 997                          none          58             73             68
# 996                     completed          73             71             68
# 995                     completed          60             64             74
# ...                           ...         ...            ...            ...
# 4                            none          52             59             56
# 3                            none          67             64             70
# 2                       completed          68             51             57
# 1                            none          54             48             52
# 0                            none          69             77             73
#
#              average
# new_index
# 999        51.333333
# 998        75.000000
# 997        66.333333
# 996        70.666667
# 995        66.000000
# ...              ...
# 4          55.666667
# 3          67.000000
# 2          58.666667
# 1          51.333333
# 0          73.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Rename Column

# %%
# rename column and overwrite values of the dataframe
df_exams = df_exams.rename(columns={'gender': 'Gender'})

# %%
df_exams
# Out:
#            Gender race/ethnicity parental level of education         lunch  \
# new_index
# 999          male        group B             master's degree  free/reduced
# 998          male        group E           bachelor's degree  free/reduced
# 997        female        group C          associate's degree      standard
# 996          male        group B                 high school      standard
# 995        female        group C                 high school      standard
# ...           ...            ...                         ...           ...
# 4          female        group D          associate's degree  free/reduced
# 3            male        group D                some college      standard
# 2            male        group E            some high school      standard
# 1          female        group C                some college      standard
# 0          female        group D                 high school      standard
#
#           test preparation course  math score  reading score  writing score  \
# new_index
# 999                          none          49             53             52
# 998                     completed          79             74             72
# 997                          none          58             73             68
# 996                     completed          73             71             68
# 995                     completed          60             64             74
# ...                           ...         ...            ...            ...
# 4                            none          52             59             56
# 3                            none          67             64             70
# 2                       completed          68             51             57
# 1                            none          54             48             52
# 0                            none          69             77             73
#
#              average
# new_index
# 999        51.333333
# 998        75.000000
# 997        66.333333
# 996        70.666667
# 995        66.000000
# ...              ...
# 4          55.666667
# 3          67.000000
# 2          58.666667
# 1          51.333333
# 0          73.000000
#
# [1000 rows x 9 columns]

# %%
# rename multiple columns and update the dataframe with inplace argument
df_exams.rename(columns={'math score': 'MS', 'reading score': 'RS', 'writing score': 'WS'}, inplace=True)

# %%
# show dataframe
df_exams
# Out:
#            Gender race/ethnicity parental level of education         lunch  \
# new_index
# 999          male        group B             master's degree  free/reduced
# 998          male        group E           bachelor's degree  free/reduced
# 997        female        group C          associate's degree      standard
# 996          male        group B                 high school      standard
# 995        female        group C                 high school      standard
# ...           ...            ...                         ...           ...
# 4          female        group D          associate's degree  free/reduced
# 3            male        group D                some college      standard
# 2            male        group E            some high school      standard
# 1          female        group C                some college      standard
# 0          female        group D                 high school      standard
#
#           test preparation course  MS  RS  WS    average
# new_index
# 999                          none  49  53  52  51.333333
# 998                     completed  79  74  72  75.000000
# 997                          none  58  73  68  66.333333
# 996                     completed  73  71  68  70.666667
# 995                     completed  60  64  74  66.000000
# ...                           ...  ..  ..  ..        ...
# 4                            none  52  59  56  55.666667
# 3                            none  67  64  70  67.000000
# 2                       completed  68  51  57  58.666667
# 1                            none  54  48  52  51.333333
# 0                            none  69  77  73  73.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Rename index

# %%
# rename index 0, 1 and 2 and update the dataframe
df_exams.rename(index={0: 'A', 1: 'B', 2: 'C',}, inplace=True)

# %%
# show last 3 rows
df_exams.tail(3)
# Out:
#            Gender race/ethnicity parental level of education     lunch  \
# new_index
# C            male        group E            some high school  standard
# B          female        group C                some college  standard
# A          female        group D                 high school  standard
#
#           test preparation course  MS  RS  WS    average
# new_index
# C                       completed  68  51  57  58.666667
# B                            none  54  48  52  51.333333
# A                            none  69  77  73  73.000000
